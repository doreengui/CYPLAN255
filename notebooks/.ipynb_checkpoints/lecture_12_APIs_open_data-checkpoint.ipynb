# %% [markdown]
# # CYPLAN255
# ### Urban Informatics and Visualization

# %% [markdown]
# HIT RECORD and TRANSCRIBE

# %% [markdown]
# # Lecture 12 -- APIs and Beyond <img src="https://i.imgur.com/HMHNjAq.jpg" width=550 align='right' title="Scottish child actress, Binkie Stuart (1932 - 2001) hand in hand with a penguin during a visit to London Zoo, 15th April 1937. (Photo by Fox Photos/Hulton Archive/Getty Images)">
# ******
# March 7, 2022

# %% [markdown]
# # Agenda
# 1. Announcements
# 2. Review: APIs + JSON
# 2. Geocoding APIs
# 3. The Census API
# 4. Summary
# 5. For next time
# 6. Questions

# %% [markdown]
# # 1. Announcements

# %% [markdown]
# - Assignment 4 (project proposal + initial analysis) due March 13
# - Final Project description released tonight
# - How far we've come

# %% [markdown]
# ## How Far We've Come
#
# 1. ~Fundamentals of Programming~
# 1. ~Intro to Data Analysis in Python~
# 1. ~Intro to Data Visualization~
# 1. APIs + Open Data
# 1. Working with Geospatial Data
# 1. Visualizing Spatial Data
# 1. Statistical Analysis + Machine Learning

# %% [markdown]
# # 2. Review: APIs + JSON

# %% [markdown]
# So far we've seen how you can use an API to download data stored as a .json file in some static location. That's cool, but ultimately not that different from clicking a link and downloading a file to your desktop. It also presumes you know the URL you want ahead of time, and that you want to download the entire file.
#
# Today we're going to be seeing how you can use APIs to interact with _services_, i.e. APIs that perform operations and generate the data you want on demand. To continue with the restaurant analogy, we started off ordering fast food burgers, but now we're ready for the tasting menu at Chez Panisse.

# %% [markdown]
# <img src="https://i.kym-cdn.com/photos/images/original/001/474/943/b12.jpg" width=200 align="right">

# %% [markdown]
# But before we get there, let's quickly review what we've learned so far by checking out the USGS real-time earthquake data API.
#
# ### 2.1. USGS real-time earthquake feeds
#
# This is an API for near-real-time data about earthquakes. Data is provided in JSON format over the web. No authentication is needed, and there's no way to customize the output. Instead, the API has a separate endpoint for each permutation of the data that users might want.
#
# **API documentation:**
# http://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson.php
#
# **Sample API endpoint, for magnitude 4.5+ earthquakes in past day:**
# http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_day.geojson

# %% [markdown]
# We'll start by querying the endpoint for magnitude 2.5+ quakes from the past week:

# %%
import pandas as pd
import json    
import requests
import pprint
pp = pprint.PrettyPrinter

endpoint_url = "http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson"
response = requests.get(endpoint_url)
print(response.text[:500])
# Out:
# {"type":"FeatureCollection","metadata":{"generated":1646850422000,"url":"https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson","title":"USGS Magnitude 2.5+ Earthquakes, Past Week","status":200,"api":"1.10.3","count":288},"features":[{"type":"Feature","properties":{"mag":4.8,"place":"44 km NE of Calama, Chile","time":1646849043457,"updated":1646850120040,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us6000h3cz","detail":"https://earthquake.usgs.gov/earth

# %% [markdown]
# It looks like the results are a string with JSON-formatted data inside, so we'll parse the string into a Python dictionary using `json.loads()`:

# %%
data = json.loads(response.text)
data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1646850422000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson',
#   'title': 'USGS Magnitude 2.5+ Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 288},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '44 km NE of Calama, Chile',
#     'time': 1646849043457,
#     'updated': 1646850120040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h3cz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h3cz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '6000h3cz',
#     'ids': ',us6000h3cz,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.712,
#     'rms': 1.52,
#     'gap': 58,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 44 km NE of Calama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.6028, -22.1939, 111.19]},
#    'id': 'us6000h3cz'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.53,
#     'place': '9km N of Petrolia, CA',
#     'time': 1646848487210,
#     'updated': 1646849122718,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73703361',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73703361.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'nc',
#     'code': '73703361',
#     'ids': ',nc73703361,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 16,
#     'dmin': 0.08162,
#     'rms': 0.07,
#     'gap': 183,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 9km N of Petrolia, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-124.2675018, 40.402668, 26.24]},
#    'id': 'nc73703361'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '36 km NNE of Excursion Inlet, Alaska',
#     'time': 1646845405783,
#     'updated': 1646848489185,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak02234qonr5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02234qonr5.geojson',
#     'felt': 2,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'ak',
#     'code': '02234qonr5',
#     'ids': ',ak02234qonr5,us6000h3bi,',
#     'sources': ',ak,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.09,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 36 km NNE of Excursion Inlet, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-135.2233, 58.721, 17.7]},
#    'id': 'ak02234qonr5'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '95 km SE of Old Harbor, Alaska',
#     'time': 1646843542006,
#     'updated': 1646844241925,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak02234q9fy0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02234q9fy0.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 1,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 188,
#     'net': 'ak',
#     'code': '02234q9fy0',
#     'ids': ',ak02234q9fy0,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.75,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 95 km SE of Old Harbor, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.1622, 56.615, 0]},
#    'id': 'ak02234q9fy0'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': 'South Sandwich Islands region',
#     'time': 1646843414969,
#     'updated': 1646844832188,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h3b9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h3b9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 2.689,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '6000h3b9',
#     'ids': ',us6000h3b9,',
#     'sources': ',us,',
#     'types': ',losspager,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 8.561,
#     'rms': 0.71,
#     'gap': 78,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.5 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-25.965, -60.6957, 10]},
#    'id': 'us6000h3b9'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': 'Galapagos Triple Junction region',
#     'time': 1646842681292,
#     'updated': 1646843689040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h3b7',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h3b7.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '6000h3b7',
#     'ids': ',us6000h3b7,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 15.183,
#     'rms': 1.02,
#     'gap': 198,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - Galapagos Triple Junction region'},
#    'geometry': {'type': 'Point', 'coordinates': [-100.7168, 6.0158, 10]},
#    'id': 'us6000h3b7'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.82,
#     'place': '32 km NW of Stanley, Idaho',
#     'time': 1646838659330,
#     'updated': 1646842331830,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb80540019',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb80540019.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 122,
#     'net': 'mb',
#     'code': '80540019',
#     'ids': ',mb80540019,',
#     'sources': ',mb,',
#     'types': ',origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.866,
#     'rms': 0.26,
#     'gap': 59,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 32 km NW of Stanley, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.216, 44.4258333, 11.36]},
#    'id': 'mb80540019'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '40 km SSE of Mendeltna, Alaska',
#     'time': 1646837909075,
#     'updated': 1646839399157,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak02234p85vf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02234p85vf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '02234p85vf',
#     'ids': ',ak02234p85vf,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.78,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 40 km SSE of Mendeltna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-146.2213, 61.7213, 6]},
#    'id': 'ak02234p85vf'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.54,
#     'place': '2 km SW of Santo Domingo, Puerto Rico',
#     'time': 1646837229120,
#     'updated': 1646850233478,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339658',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339658.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 99,
#     'net': 'pr',
#     'code': '71339658',
#     'ids': ',pr71339658,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 7,
#     'dmin': None,
#     'rms': 0.3,
#     'gap': 142,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 2 km SW of Santo Domingo, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.7713333333333, 18.0505, 8.86]},
#    'id': 'pr71339658'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.77,
#     'place': '1 km SW of Tallaboa, Puerto Rico',
#     'time': 1646834022110,
#     'updated': 1646835371970,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339653',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339653.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 118,
#     'net': 'pr',
#     'code': '71339653',
#     'ids': ',pr71339653,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': None,
#     'rms': 0.15,
#     'gap': 149,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 1 km SW of Tallaboa, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.726, 17.9876666666667, 7.26]},
#    'id': 'pr71339653'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.51,
#     'place': '1 km ESE of Maria Antonia, Puerto Rico',
#     'time': 1646833909900,
#     'updated': 1646835166300,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339648',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339648.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 97,
#     'net': 'pr',
#     'code': '71339648',
#     'ids': ',pr71339648,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': None,
#     'rms': 0.12,
#     'gap': 201,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 1 km ESE of Maria Antonia, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8731666666667, 17.9716666666667, 16.28]},
#    'id': 'pr71339648'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '10 km S of Kodiak, Alaska',
#     'time': 1646832375082,
#     'updated': 1646849330889,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak02234ofu70',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02234ofu70.geojson',
#     'felt': 3,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 139,
#     'net': 'ak',
#     'code': '02234ofu70',
#     'ids': ',ak02234ofu70,',
#     'sources': ',ak,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.54,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 10 km S of Kodiak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.4003, 57.696, 26.4]},
#    'id': 'ak02234ofu70'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '16 km SW of Sunrise, Alaska',
#     'time': 1646830958462,
#     'updated': 1646843286788,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak02234oaqsf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02234oaqsf.geojson',
#     'felt': 16,
#     'cdi': 3.8,
#     'mmi': 2.672,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 195,
#     'net': 'ak',
#     'code': '02234oaqsf',
#     'ids': ',ak02234oaqsf,',
#     'sources': ',ak,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.5,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 16 km SW of Sunrise, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.6136, 60.769, 26.9]},
#    'id': 'ak02234oaqsf'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.2,
#     'place': '79 km SSW of Hualien City, Taiwan',
#     'time': 1646828534494,
#     'updated': 1646835336825,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h39z',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h39z.geojson',
#     'felt': 7,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 419,
#     'net': 'us',
#     'code': '6000h39z',
#     'ids': ',us6000h39z,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.152,
#     'rms': 0.75,
#     'gap': 50,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.2 - 79 km SSW of Hualien City, Taiwan'},
#    'geometry': {'type': 'Point', 'coordinates': [121.4126, 23.282, 32.49]},
#    'id': 'us6000h39z'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.9,
#     'place': '205 km WSW of Adak, Alaska',
#     'time': 1646825496555,
#     'updated': 1646832696702,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h39t',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h39t.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 2.461,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 234,
#     'net': 'us',
#     'code': '6000h39t',
#     'ids': ',ak02234na34q,us6000h39t,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.906,
#     'rms': 0.71,
#     'gap': 227,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.9 - 205 km WSW of Adak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-179.182, 50.9453, 35]},
#    'id': 'us6000h39t'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '135 km SSW of Ōyama, Japan',
#     'time': 1646822357775,
#     'updated': 1646826240040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h39n',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h39n.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000h39n',
#     'ids': ',us6000h39n,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.282,
#     'rms': 0.93,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 135 km SSW of Ōyama, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [137.9029, 33.4131, 346.7]},
#    'id': 'us6000h39n'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.89,
#     'place': '3 km W of La Parguera, Puerto Rico',
#     'time': 1646821324910,
#     'updated': 1646824244939,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339643',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339643.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'pr',
#     'code': '71339643',
#     'ids': ',pr71339643,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 16,
#     'dmin': None,
#     'rms': 0.26,
#     'gap': 214,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 3 km W of La Parguera, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.0815, 17.978, 7.72]},
#    'id': 'pr71339643'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.8,
#     'place': '105 km SSE of Sand Point, Alaska',
#     'time': 1646819790344,
#     'updated': 1646832257434,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h39c',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h39c.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 2.087,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 222,
#     'net': 'us',
#     'code': '6000h39c',
#     'ids': ',ak02234m8kpg,us6000h39c,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.957,
#     'rms': 0.8,
#     'gap': 186,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 105 km SSE of Sand Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-159.6038, 54.5368, 19.89]},
#    'id': 'us6000h39c'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.6,
#     'place': '41 km SSE of False Pass, Alaska',
#     'time': 1646819546985,
#     'updated': 1646820898040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h39b',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h39b.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 199,
#     'net': 'us',
#     'code': '6000h39b',
#     'ids': ',us6000h39b,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.379,
#     'rms': 0.69,
#     'gap': 187,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 41 km SSE of False Pass, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-163.2578, 54.4896, 10]},
#    'id': 'us6000h39b'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '71 km WNW of Alatna, Alaska',
#     'time': 1646816131439,
#     'updated': 1646819306040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak02234lmx6y',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02234lmx6y.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'ak',
#     'code': '02234lmx6y',
#     'ids': ',us6000h38y,ak02234lmx6y,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.11,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 71 km WNW of Alatna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-154.1881, 66.8227, 13]},
#    'id': 'ak02234lmx6y'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.49,
#     'place': '23 km SW of Esperanza, Puerto Rico',
#     'time': 1646815714310,
#     'updated': 1646819073540,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339623',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339623.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'pr',
#     'code': '71339623',
#     'ids': ',pr71339623,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': None,
#     'rms': 0.32,
#     'gap': 231,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 23 km SW of Esperanza, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-65.625, 17.9495, 13.37]},
#    'id': 'pr71339623'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '2 km ESE of Yauco, Puerto Rico',
#     'time': 1646812027710,
#     'updated': 1646813818160,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339613',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339613.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'pr',
#     'code': '71339613',
#     'ids': ',pr71339613,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': None,
#     'rms': 0.21,
#     'gap': 107,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 2 km ESE of Yauco, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8276666666667, 18.0296666666667, 12.82]},
#    'id': 'pr71339613'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.66,
#     'place': '13 km WNW of Stanley, Idaho',
#     'time': 1646810671590,
#     'updated': 1646847305190,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb80540009',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb80540009.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 109,
#     'net': 'mb',
#     'code': '80540009',
#     'ids': ',mb80540009,',
#     'sources': ',mb,',
#     'types': ',origin,phase-data,',
#     'nst': 24,
#     'dmin': 0.865,
#     'rms': 0.25,
#     'gap': 67,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 13 km WNW of Stanley, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.077, 44.2823333, 7.44]},
#    'id': 'mb80540009'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.45,
#     'place': '3 km SSW of Liborio Negron Torres, Puerto Rico',
#     'time': 1646807774630,
#     'updated': 1646819750177,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339603',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339603.geojson',
#     'felt': 0,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 92,
#     'net': 'pr',
#     'code': '71339603',
#     'ids': ',pr71339603,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 5,
#     'dmin': None,
#     'rms': 0.06,
#     'gap': 121,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 3 km SSW of Liborio Negron Torres, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.9501666666667, 18.0133333333333, 10.3]},
#    'id': 'pr71339603'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.07,
#     'place': '28 km N of Arecibo, Puerto Rico',
#     'time': 1646800878860,
#     'updated': 1646807587170,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339588',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339588.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 145,
#     'net': 'pr',
#     'code': '71339588',
#     'ids': ',pr71339588,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': None,
#     'rms': 0.2,
#     'gap': 249,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 28 km N of Arecibo, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.706, 18.7315, 35.7]},
#    'id': 'pr71339588'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '28 km N of Opotiki, New Zealand',
#     'time': 1646793884842,
#     'updated': 1646801312516,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h37j',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h37j.geojson',
#     'felt': 22,
#     'cdi': 4.1,
#     'mmi': 3.677,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 409,
#     'net': 'us',
#     'code': '6000h37j',
#     'ids': ',us6000h37j,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.794,
#     'rms': 0.78,
#     'gap': 53,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 28 km N of Opotiki, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [177.3363, -37.758, 77.81]},
#    'id': 'us6000h37j'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': 'West Chile Rise',
#     'time': 1646791625737,
#     'updated': 1646795166040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h37h',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h37h.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '6000h37h',
#     'ids': ',us6000h37h,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 15.289,
#     'rms': 0.86,
#     'gap': 52,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.1 - West Chile Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-93.0291, -38.3861, 10]},
#    'id': 'us6000h37h'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '30 km SSE of Jaqué, Panama',
#     'time': 1646791520776,
#     'updated': 1646792701040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h37d',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h37d.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000h37d',
#     'ids': ',us6000h37d,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.321,
#     'rms': 0.95,
#     'gap': 105,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 30 km SSE of Jaqué, Panama'},
#    'geometry': {'type': 'Point', 'coordinates': [-78.0744, 7.2553, 10]},
#    'id': 'us6000h37d'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '105 km NNE of Tobelo, Indonesia',
#     'time': 1646790559867,
#     'updated': 1646791689040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h37b',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h37b.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '6000h37b',
#     'ids': ',us6000h37b,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.088,
#     'rms': 0.84,
#     'gap': 82,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 105 km NNE of Tobelo, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [128.433, 2.5805, 53.24]},
#    'id': 'us6000h37b'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '138 km NE of Petropavlovsk-Kamchatsky, Russia',
#     'time': 1646787499742,
#     'updated': 1646789618040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h375',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h375.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000h375',
#     'ids': ',us6000h375,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.267,
#     'rms': 0.74,
#     'gap': 126,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 138 km NE of Petropavlovsk-Kamchatsky, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [160.2322, 53.8644, 64.58]},
#    'id': 'us6000h375'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': 'southern Iran',
#     'time': 1646781698981,
#     'updated': 1646783158040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h36i',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h36i.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000h36i',
#     'ids': ',us6000h36i,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.618,
#     'rms': 0.86,
#     'gap': 83,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - southern Iran'},
#    'geometry': {'type': 'Point', 'coordinates': [56.0146, 27.5689, 10]},
#    'id': 'us6000h36i'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '0 km WNW of Nueva Concepción, Guatemala',
#     'time': 1646776437927,
#     'updated': 1646780072040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h35x',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h35x.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '6000h35x',
#     'ids': ',us6000h35x,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.508,
#     'rms': 0.96,
#     'gap': 162,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 0 km WNW of Nueva Concepción, Guatemala'},
#    'geometry': {'type': 'Point', 'coordinates': [-91.304, 14.2012, 81.47]},
#    'id': 'us6000h35x'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '98 km SSW of Chirilagua, El Salvador',
#     'time': 1646775596823,
#     'updated': 1646779129040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h35u',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h35u.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h35u',
#     'ids': ',us6000h35u,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.082,
#     'rms': 1.01,
#     'gap': 197,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 98 km SSW of Chirilagua, El Salvador'},
#    'geometry': {'type': 'Point', 'coordinates': [-88.4616, 12.3885, 33.35]},
#    'id': 'us6000h35u'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.6,
#     'place': '10 km SSE of Point Possession, Alaska',
#     'time': 1646774885060,
#     'updated': 1646818160641,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022335od6n',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak022335od6n.geojson',
#     'felt': 25,
#     'cdi': 3.4,
#     'mmi': 2.216,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 208,
#     'net': 'ak',
#     'code': '022335od6n',
#     'ids': ',ak022335od6n,us6000h35n,',
#     'sources': ',ak,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.77,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 10 km SSE of Point Possession, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.6127, 60.8328, 45.1]},
#    'id': 'ak022335od6n'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '7 km SW of Gypsum, Kansas',
#     'time': 1646771843247,
#     'updated': 1646833068251,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h34z',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h34z.geojson',
#     'felt': 4,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 140,
#     'net': 'us',
#     'code': '6000h34z',
#     'ids': ',us6000h34z,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.717,
#     'rms': 0.46,
#     'gap': 99,
#     'magType': 'mb_lg',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 7 km SW of Gypsum, Kansas'},
#    'geometry': {'type': 'Point', 'coordinates': [-97.4806, 38.6532, 5]},
#    'id': 'us6000h34z'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': 'Kermadec Islands, New Zealand',
#     'time': 1646766485601,
#     'updated': 1646768057040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h34m',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h34m.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '6000h34m',
#     'ids': ',us6000h34m,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.385,
#     'rms': 0.7,
#     'gap': 69,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - Kermadec Islands, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.1561, -30.4823, 10]},
#    'id': 'us6000h34m'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.8,
#     'place': '112 km SW of Nikolski, Alaska',
#     'time': 1646765084180,
#     'updated': 1646770362040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h34l',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h34l.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 222,
#     'net': 'us',
#     'code': '6000h34l',
#     'ids': ',ak022333zpje,us6000h34l,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.041,
#     'rms': 1.13,
#     'gap': 179,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 112 km SW of Nikolski, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-170.0887, 52.2532, 47.27]},
#    'id': 'us6000h34l'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.47,
#     'place': '5 km WSW of Guánica, Puerto Rico',
#     'time': 1646764401830,
#     'updated': 1646765738950,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339538',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339538.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 94,
#     'net': 'pr',
#     'code': '71339538',
#     'ids': ',pr71339538,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': None,
#     'rms': 0.09,
#     'gap': 209,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 5 km WSW of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.9568333333333, 17.9503333333333, 7.4]},
#    'id': 'pr71339538'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.6,
#     'place': '201 km SE of Perryville, Alaska',
#     'time': 1646761010239,
#     'updated': 1646849741040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022333ckw3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak022333ckw3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 1,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 199,
#     'net': 'ak',
#     'code': '022333ckw3',
#     'ids': ',us6000h33x,ak022333ckw3,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.67,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 201 km SE of Perryville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-156.8853, 54.6373, 23.7]},
#    'id': 'ak022333ckw3'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': 'west of Macquarie Island',
#     'time': 1646759676909,
#     'updated': 1646846284449,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h33h',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h33h.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '6000h33h',
#     'ids': ',us6000h33h,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 7.7,
#     'rms': 0.68,
#     'gap': 53,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - west of Macquarie Island'},
#    'geometry': {'type': 'Point', 'coordinates': [145.8055, -54.1448, 10]},
#    'id': 'us6000h33h'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.6,
#     'place': '10 km ENE of Pāhala, Hawaii',
#     'time': 1646758185340,
#     'updated': 1646844712578,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72943142',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72943142.geojson',
#     'felt': 33,
#     'cdi': 3.1,
#     'mmi': 3.883,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 210,
#     'net': 'hv',
#     'code': '72943142',
#     'ids': ',hv72943142,us6000h327,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': 51,
#     'dmin': None,
#     'rms': 0.14,
#     'gap': 140,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 10 km ENE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point', 'coordinates': [-155.3855, 19.245, 31.7]},
#    'id': 'hv72943142'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '23 km WSW of Bulls, New Zealand',
#     'time': 1646757326036,
#     'updated': 1646758002040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h321',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h321.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000h321',
#     'ids': ',us6000h321,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.529,
#     'rms': 0.9,
#     'gap': 100,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 23 km WSW of Bulls, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [175.1266, -40.2584, 104.31]},
#    'id': 'us6000h321'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.56,
#     'place': '11 km E of Pāhala, Hawaii',
#     'time': 1646751888870,
#     'updated': 1646753987040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72943052',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72943052.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 101,
#     'net': 'hv',
#     'code': '72943052',
#     'ids': ',us6000h31h,hv72943052,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 48,
#     'dmin': None,
#     'rms': 0.119999997,
#     'gap': 160,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 11 km E of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.371337890625, 19.2096672058105, 32.4300003051758]},
#    'id': 'hv72943052'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '135 km WNW of Naha, Japan',
#     'time': 1646750823638,
#     'updated': 1646752810040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h31g',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h31g.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '6000h31g',
#     'ids': ',us6000h31g,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.547,
#     'rms': 0.64,
#     'gap': 52,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 135 km WNW of Naha, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [126.5404, 26.8735, 10]},
#    'id': 'us6000h31g'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '56 km WSW of Abra Pampa, Argentina',
#     'time': 1646749905350,
#     'updated': 1646753412040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h31c',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h31c.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h31c',
#     'ids': ',us6000h31c,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.803,
#     'rms': 0.39,
#     'gap': 45,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 56 km WSW of Abra Pampa, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.2242, -22.8813, 218.56]},
#    'id': 'us6000h31c'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '76 km SE of Farkhār, Afghanistan',
#     'time': 1646749335158,
#     'updated': 1646751328040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h31a',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h31a.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000h31a',
#     'ids': ',us6000h31a,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.013,
#     'rms': 0.79,
#     'gap': 109,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 76 km SE of Farkhār, Afghanistan'},
#    'geometry': {'type': 'Point', 'coordinates': [70.4874, 36.1122, 101.09]},
#    'id': 'us6000h31a'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '15 km NNW of Atka, Alaska',
#     'time': 1646748334337,
#     'updated': 1646775072040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h34t',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h34t.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'us',
#     'code': '6000h34t',
#     'ids': ',av91507256,us6000h34t,',
#     'sources': ',av,us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.039,
#     'rms': 0.43,
#     'gap': 123,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 15 km NNW of Atka, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-174.2791, 52.3287, 7.3]},
#    'id': 'us6000h34t'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '73 km E of Dennery, Saint Lucia',
#     'time': 1646747781203,
#     'updated': 1646754835425,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h318',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h318.geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 285,
#     'net': 'us',
#     'code': '6000h318',
#     'ids': ',us6000h318,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.948,
#     'rms': 0.14,
#     'gap': 93,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 73 km E of Dennery, Saint Lucia'},
#    'geometry': {'type': 'Point', 'coordinates': [-60.2253, 14.0303, 32.99]},
#    'id': 'us6000h318'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '128 km WNW of Naha, Japan',
#     'time': 1646746105229,
#     'updated': 1646750114040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h314',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h314.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h314',
#     'ids': ',us6000h314,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.515,
#     'rms': 0.95,
#     'gap': 64,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 128 km WNW of Naha, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [126.577, 26.8194, 10]},
#    'id': 'us6000h314'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '215 km WSW of Olonkinbyen, Svalbard and Jan Mayen',
#     'time': 1646745651449,
#     'updated': 1646749407040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h312',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h312.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '6000h312',
#     'ids': ',us6000h312,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.504,
#     'rms': 1.01,
#     'gap': 55,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 215 km WSW of Olonkinbyen, Svalbard and Jan Mayen'},
#    'geometry': {'type': 'Point', 'coordinates': [-14.4821, 70.5717, 10]},
#    'id': 'us6000h312'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.51,
#     'place': '9 km SSE of Maria Antonia, Puerto Rico',
#     'time': 1646742456670,
#     'updated': 1646744600460,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71339488',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71339488.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 97,
#     'net': 'pr',
#     'code': '71339488',
#     'ids': ',pr71339488,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 23,
#     'dmin': None,
#     'rms': 0.2,
#     'gap': 197,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 9 km SSE of Maria Antonia, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8516666666667, 17.9045, 12.25]},
#    'id': 'pr71339488'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '130 km WNW of Naha, Japan',
#     'time': 1646736825668,
#     'updated': 1646743808040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h30n',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h30n.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h30n',
#     'ids': ',us6000h30n,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.521,
#     'rms': 0.43,
#     'gap': 80,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 130 km WNW of Naha, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [126.5701, 26.8324, 10]},
#    'id': 'us6000h30n'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '104 km WNW of Iquique, Chile',
#     'time': 1646735751786,
#     'updated': 1646750113287,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h30e',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h30e.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '6000h30e',
#     'ids': ',us6000h30e,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.974,
#     'rms': 0.34,
#     'gap': 144,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 104 km WNW of Iquique, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.1156, -19.9643, 13.93]},
#    'id': 'us6000h30e'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '129 km WNW of Naha, Japan',
#     'time': 1646734144514,
#     'updated': 1646742543040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h308',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h308.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h308',
#     'ids': ',us6000h308,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.523,
#     'rms': 0.34,
#     'gap': 39,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 129 km WNW of Naha, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [126.5675, 26.8161, 10]},
#    'id': 'us6000h308'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '208 km W of Olonkinbyen, Svalbard and Jan Mayen',
#     'time': 1646729802644,
#     'updated': 1646731690040,
# ...
#    'geometry': {'type': 'Point', 'coordinates': [-83.1799, -42.6203, 10]},
#    'id': 'us6000h1lf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '147 km NW of Nuku‘alofa, Tonga',
#     'time': 1646264847838,
#     'updated': 1646267339040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1kf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1kf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '6000h1kf',
#     'ids': ',us6000h1kf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 6.055,
#     'rms': 0.93,
#     'gap': 144,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 147 km NW of Nuku‘alofa, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-176.0282, -20.055, 231.2]},
#    'id': 'us6000h1kf'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '37 km NE of Sorong, Indonesia',
#     'time': 1646263519871,
#     'updated': 1646264592040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1k6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1k6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '6000h1k6',
#     'ids': ',us6000h1k6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 2.429,
#     'rms': 0.67,
#     'gap': 117,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 37 km NE of Sorong, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [131.4612, -0.6056, 10]},
#    'id': 'us6000h1k6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '182 km SW of Lorengau, Papua New Guinea',
#     'time': 1646262413758,
#     'updated': 1646279067040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1kc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1kc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '6000h1kc',
#     'ids': ',us6000h1kc,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.691,
#     'rms': 0.92,
#     'gap': 77,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 182 km SW of Lorengau, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [146.3381, -3.396, 12.16]},
#    'id': 'us6000h1kc'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.73,
#     'place': '20km NW of Desert Center, CA',
#     'time': 1646261702670,
#     'updated': 1646697310137,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40198320',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40198320.geojson',
#     'felt': 4,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'ci',
#     'code': '40198320',
#     'ids': ',ci40198320,us6000h1jr,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 40,
#     'dmin': 0.166,
#     'rms': 0.15,
#     'gap': 41,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 20km NW of Desert Center, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.5431667, 33.8533333, 1.78]},
#    'id': 'ci40198320'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '63 km S of Kokopo, Papua New Guinea',
#     'time': 1646261639418,
#     'updated': 1646348221578,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1jt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1jt.geojson',
#     'felt': 2,
#     'cdi': 4.5,
#     'mmi': 4.044,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 466,
#     'net': 'us',
#     'code': '6000h1jt',
#     'ids': ',us6000h1jt,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 8.905,
#     'rms': 0.76,
#     'gap': 52,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 63 km S of Kokopo, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [152.2002, -4.9103, 41.69]},
#    'id': 'us6000h1jt'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.01,
#     'place': '33 km WNW of Kalaoa, Hawaii',
#     'time': 1646253613080,
#     'updated': 1646775589040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72935302',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72935302.geojson',
#     'felt': 4,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 140,
#     'net': 'hv',
#     'code': '72935302',
#     'ids': ',hv72935302,us6000h1ig,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 43,
#     'dmin': None,
#     'rms': 0.21,
#     'gap': 285,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 33 km WNW of Kalaoa, Hawaii'},
#    'geometry': {'type': 'Point', 'coordinates': [-156.271, 19.858, 42.28]},
#    'id': 'hv72935302'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': 'West Chile Rise',
#     'time': 1646252382764,
#     'updated': 1646775154040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1ic',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1ic.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h1ic',
#     'ids': ',us6000h1ic,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 8.272,
#     'rms': 0.66,
#     'gap': 214,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - West Chile Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-82.7812, -42.5595, 10]},
#    'id': 'us6000h1ic'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.15,
#     'place': '4 km SW of Pāhala, Hawaii',
#     'time': 1646251914120,
#     'updated': 1646772193252,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72935282',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv72935282.geojson',
#     'felt': 5,
#     'cdi': 3.4,
#     'mmi': 3.714,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 154,
#     'net': 'hv',
#     'code': '72935282',
#     'ids': ',hv72935282,us6000h1i9,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': 55,
#     'dmin': None,
#     'rms': 0.12,
#     'gap': 93,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 4 km SW of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.506833333333, 19.174, 36.51]},
#    'id': 'hv72935282'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.4,
#     'place': 'north of Ascension Island',
#     'time': 1646251660726,
#     'updated': 1646768665807,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1ia',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1ia.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 449,
#     'net': 'us',
#     'code': '6000h1ia',
#     'ids': ',us6000h1ia,',
#     'sources': ',us,',
#     'types': ',losspager,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 8.317,
#     'rms': 0.69,
#     'gap': 43,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.4 - north of Ascension Island'},
#    'geometry': {'type': 'Point', 'coordinates': [-16.9871, 0.1599, 10]},
#    'id': 'us6000h1ia'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.98,
#     'place': '4 km N of Animas, Puerto Rico',
#     'time': 1646251646360,
#     'updated': 1646281844861,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71338583',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71338583.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 137,
#     'net': 'pr',
#     'code': '71338583',
#     'ids': ',pr71338583,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 9,
#     'dmin': None,
#     'rms': 0.29,
#     'gap': 232,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 4 km N of Animas, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.6298333333333, 18.4871666666667, 91.6]},
#    'id': 'pr71338583'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '13 km SW of Vardane, Russia',
#     'time': 1646250959127,
#     'updated': 1646767706527,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1le',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1le.geojson',
#     'felt': 3,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 139,
#     'net': 'us',
#     'code': '6000h1le',
#     'ids': ',us6000h1le,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': None,
#     'dmin': 2.363,
#     'rms': 0.56,
#     'gap': 102,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 13 km SW of Vardane, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [39.4532, 43.6332, 10]},
#    'id': 'us6000h1le'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': 'Ryukyu Islands, Japan',
#     'time': 1646249448085,
#     'updated': 1646767391040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1i0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1i0.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h1i0',
#     'ids': ',us6000h1i0,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.643,
#     'rms': 0.91,
#     'gap': 78,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - Ryukyu Islands, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [126.4352, 26.7651, 10]},
#    'id': 'us6000h1i0'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '261 km WSW of Tual, Indonesia',
#     'time': 1646249155437,
#     'updated': 1646767004040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2sg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2sg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '6000h2sg',
#     'ids': ',us6000h2sg,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.424,
#     'rms': 0.6,
#     'gap': 129,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 261 km WSW of Tual, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [130.6508, -6.7031, 123.54]},
#    'id': 'us6000h2sg'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '65 km WNW of La Ligua, Chile',
#     'time': 1646248708162,
#     'updated': 1646764625040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1hs',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1hs.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000h1hs',
#     'ids': ',us6000h1hs,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 0.785,
#     'rms': 0.9,
#     'gap': 175,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 65 km WNW of La Ligua, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.8878, -32.2615, 19.31]},
#    'id': 'us6000h1hs'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '36 km S of Nabire, Indonesia',
#     'time': 1646248479941,
#     'updated': 1646764150040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1ht',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1ht.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '6000h1ht',
#     'ids': ',us6000h1ht,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 3.354,
#     'rms': 1.09,
#     'gap': 42,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 36 km S of Nabire, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [135.5213, -3.6867, 10]},
#    'id': 'us6000h1ht'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.83,
#     'place': '8km NNE of Walker, CA',
#     'time': 1646248221150,
#     'updated': 1646763259040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73700131',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73700131.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 123,
#     'net': 'nc',
#     'code': '73700131',
#     'ids': ',nc73700131,nn00834770,us6000h1hp,',
#     'sources': ',nc,nn,us,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.05638,
#     'rms': 0.09,
#     'gap': 60,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 8km NNE of Walker, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-119.4486667, 38.5778333, 6.22]},
#    'id': 'nc73700131'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '143 km WNW of Ishikawa, Japan',
#     'time': 1646247461896,
#     'updated': 1646763128040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h1hk',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h1hk.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h1hk',
#     'ids': ',us6000h1hk,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 1.562,
#     'rms': 0.59,
#     'gap': 136,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 143 km WNW of Ishikawa, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [126.5331, 27.0071, 10]},
#    'id': 'us6000h1hk'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '265 km E of Levuka, Fiji',
#     'time': 1646246769374,
#     'updated': 1646761573040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h2tr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h2tr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000h2tr',
#     'ids': ',us6000h2tr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': 3.597,
#     'rms': 0.62,
#     'gap': 122,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 265 km E of Levuka, Fiji'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.1777, -17.9715, 644.46]},
#    'id': 'us6000h2tr'}],
#  'bbox': [-179.9245, -60.6957, -2.66, 178.3565, 70.6979, 644.46]}

# %% [markdown]
# Since JSON is just a dictionary, we can access subsets of the data can with square brackets, using labels for the named elements in a key-value pair, and numerals for positional indexing of list items.
#
# Hint: whenever you see a file that ends in `.geojson`, you'll probably want to extract the data thats stored in the `features` dictionary:

# %%
quakes = data['features']
quakes[0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 4.8,
#   'place': '44 km NE of Calama, Chile',
#   'time': 1646849043457,
#   'updated': 1646850120040,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000h3cz',
#   'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h3cz.geojson',
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 354,
#   'net': 'us',
#   'code': '6000h3cz',
#   'ids': ',us6000h3cz,',
#   'sources': ',us,',
#   'types': ',origin,phase-data,',
#   'nst': None,
#   'dmin': 0.712,
#   'rms': 1.52,
#   'gap': 58,
#   'magType': 'mb',
#   'type': 'earthquake',
#   'title': 'M 4.8 - 44 km NE of Calama, Chile'},
#  'geometry': {'type': 'Point', 'coordinates': [-68.6028, -22.1939, 111.19]},
#  'id': 'us6000h3cz'}

# %% [markdown]
# Because it is a nested dictionary at this point, we can use indexing into the dictionary to extract results.  Recall our earlier use of nested dictionaries? This is why we learned how to navigate nested dictionaries:

# %%
for q in quakes:
    print(q['properties']['title'])
# Out:
# M 4.8 - 44 km NE of Calama, Chile
# M 2.5 - 9km N of Petrolia, CA
# M 3.1 - 36 km NNE of Excursion Inlet, Alaska
# M 3.5 - 95 km SE of Old Harbor, Alaska
# M 5.5 - South Sandwich Islands region
# M 5.0 - Galapagos Triple Junction region
# M 2.8 - 32 km NW of Stanley, Idaho
# M 2.5 - 40 km SSE of Mendeltna, Alaska
# M 2.5 - 2 km SW of Santo Domingo, Puerto Rico
# M 2.8 - 1 km SW of Tallaboa, Puerto Rico
# M 2.5 - 1 km ESE of Maria Antonia, Puerto Rico
# M 3.0 - 10 km S of Kodiak, Alaska
# M 3.5 - 16 km SW of Sunrise, Alaska
# M 5.2 - 79 km SSW of Hualien City, Taiwan
# M 3.9 - 205 km WSW of Adak, Alaska
# M 4.0 - 135 km SSW of Ōyama, Japan
# M 2.9 - 3 km W of La Parguera, Puerto Rico
# M 3.8 - 105 km SSE of Sand Point, Alaska
# M 3.6 - 41 km SSE of False Pass, Alaska
# M 3.3 - 71 km WNW of Alatna, Alaska
# M 2.5 - 23 km SW of Esperanza, Puerto Rico
# M 2.5 - 2 km ESE of Yauco, Puerto Rico
# M 2.7 - 13 km WNW of Stanley, Idaho
# M 2.5 - 3 km SSW of Liborio Negron Torres, Puerto Rico
# M 3.1 - 28 km N of Arecibo, Puerto Rico
# M 5.1 - 28 km N of Opotiki, New Zealand
# M 5.1 - West Chile Rise
# M 4.6 - 30 km SSE of Jaqué, Panama
# M 5.1 - 105 km NNE of Tobelo, Indonesia
# M 4.5 - 138 km NE of Petropavlovsk-Kamchatsky, Russia
# M 4.5 - southern Iran
# M 4.1 - 0 km WNW of Nueva Concepción, Guatemala
# M 4.3 - 98 km SSW of Chirilagua, El Salvador
# M 3.6 - 10 km SSE of Point Possession, Alaska
# M 3.0 - 7 km SW of Gypsum, Kansas
# M 5.0 - Kermadec Islands, New Zealand
# M 3.8 - 112 km SW of Nikolski, Alaska
# M 2.5 - 5 km WSW of Guánica, Puerto Rico
# M 3.6 - 201 km SE of Perryville, Alaska
# M 5.5 - west of Macquarie Island
# M 3.6 - 10 km ENE of Pāhala, Hawaii
# M 4.0 - 23 km WSW of Bulls, New Zealand
# M 2.6 - 11 km E of Pāhala, Hawaii
# M 4.8 - 135 km WNW of Naha, Japan
# M 4.3 - 56 km WSW of Abra Pampa, Argentina
# M 4.2 - 76 km SE of Farkhār, Afghanistan
# M 3.1 - 15 km NNW of Atka, Alaska
# M 4.3 - 73 km E of Dennery, Saint Lucia
# M 4.4 - 128 km WNW of Naha, Japan
# M 4.2 - 215 km WSW of Olonkinbyen, Svalbard and Jan Mayen
# M 2.5 - 9 km SSE of Maria Antonia, Puerto Rico
# M 4.3 - 130 km WNW of Naha, Japan
# M 4.1 - 104 km WNW of Iquique, Chile
# M 4.3 - 129 km WNW of Naha, Japan
# M 4.5 - 208 km W of Olonkinbyen, Svalbard and Jan Mayen
# M 3.9 - 30 km SSE of Boca de Yuma, Dominican Republic
# M 2.8 - 14 km ESE of Pāhala, Hawaii
# M 2.7 - 11 km E of Pāhala, Hawaii
# M 4.6 - 12 km NNW of Jérémie, Haiti
# M 4.9 - south of the Kermadec Islands
# M 4.1 - 86 km W of San Antonio de los Cobres, Argentina
# M 5.1 - South Sandwich Islands region
# M 4.8 - 123 km WNW of Ishikawa, Japan
# M 2.8 - 22km NE of San Lucas, CA
# M 2.5 - 1 km WSW of Fuig, Puerto Rico
# M 4.3 - 119 km S of Hihifo, Tonga
# M 4.0 - 198 km W of Olonkinbyen, Svalbard and Jan Mayen
# M 4.1 - 5 km S of Mugur-Aksy, Russia
# M 2.8 - 6km WNW of Bodie, CA
# M 4.5 - Fiji region
# M 2.5 - 37 km ENE of Pedro Bay, Alaska
# M 4.4 - 191 km W of Olonkinbyen, Svalbard and Jan Mayen
# M 4.7 - 55 km SE of Mohr, Iran
# M 5.1 - South Sandwich Islands region
# M 3.2 - 102 km SSE of Sand Point, Alaska
# M 5.2 - Kermadec Islands, New Zealand
# M 4.2 - 17 km SSW of Adak, Alaska
# M 4.0 - 76 km S of Adak, Alaska
# M 3.3 - off the coast of Oregon
# M 2.9 - Rat Islands, Aleutian Islands, Alaska
# M 3.2 - 11 km ENE of Pāhala, Hawaii
# M 4.3 - 33 km WSW of Tennant Creek, Australia
# M 4.4 - 198 km ESE of Namie, Japan
# M 4.9 - 7 km NNW of Cepitá, Colombia
# M 2.8 - 6km WNW of Bodie, CA
# M 5.3 - 163 km NNE of Laikit, Laikit II (Dimembe), Indonesia
# M 4.6 - 34 km S of Yonakuni, Japan
# M 3.9 - 109 km S of Adak, Alaska
# M 5.4 - southeast of Easter Island
# M 2.5 - 71 km NNE of White Mountain, Alaska
# M 4.2 - 19 km N of Jérémie, Haiti
# M 4.9 - 243 km W of Tual, Indonesia
# M 4.5 - 286 km SSW of Severo-Kuril’sk, Russia
# M 4.1 - 18 km N of Jérémie, Haiti
# M 4.8 - near the west coast of Honshu, Japan
# M 2.7 - 35 km SSW of Los Ybanez, Texas
# M 3.3 - 66 km N of Charlotte Amalie, U.S. Virgin Islands
# M 3.5 - 6km WNW of Bodie, CA
# M 2.7 - 12 km ENE of Pāhala, Hawaii
# M 4.8 - 106 km WSW of Wuwei, China
# M 2.5 - Island of Hawaii, Hawaii
# M 2.9 - 9 km SSE of Gardendale, Texas
# M 2.7 - 9 km SSE of Maria Antonia, Puerto Rico
# M 4.9 - Hokkaido, Japan region
# M 3.3 - 4 km S of Pāhala, Hawaii
# M 2.7 - 1 km SE of Indios, Puerto Rico
# M 4.4 - 29 km NNW of Labuan Lombok, Indonesia
# M 3.3 - 4 km WSW of Pāhala, Hawaii
# M 6.1 - Fiji region
# M 3.2 - 35 km WSW of Pole Ojea, Puerto Rico
# M 3.1 - 55 km S of Whites City, New Mexico
# M 2.5 - 3 km SW of Indios, Puerto Rico
# M 4.5 - 70 km NNE of Maumere, Indonesia
# M 2.8 - 180 km W of Ferndale, California
# M 3.7 - 40 km NNE of Otra Banda, Dominican Republic
# M 3.1 - 150 km W of Haines Junction, Canada
# M 5.0 - Mid-Indian Ridge
# M 4.2 - 30 km WSW of Orcopampa, Peru
# M 4.4 - 21 km SW of Pogradec, Albania
# M 4.4 - 96 km ESE of Ishinomaki, Japan
# M 4.4 - 38 km SW of Turt, Mongolia
# M 2.7 - 56 km S of Whites City, New Mexico
# M 4.8 - 227 km N of Inuvik, Canada
# M 4.3 - 209 km SE of Pondaguitan, Philippines
# M 4.4 - 38 km ESE of Farkhār, Afghanistan
# M 3.0 - 11 km SW of Akutan, Alaska
# M 6.0 - South Sandwich Islands region
# M 4.1 - 99 km W of San Antonio de los Cobres, Argentina
# M 4.1 - 129 km E of San Pedro de Atacama, Chile
# M 2.6 - 51 km E of Pedro Bay, Alaska
# M 4.2 - 140 km N of Cruz Bay, U.S. Virgin Islands
# M 2.5 - Rat Islands, Aleutian Islands, Alaska
# M 4.0 - 24 km WNW of Pucara, Peru
# M 4.4 - 77 km NNE of Ruteng, Indonesia
# M 3.9 - 21 km NNE of Skwentna, Alaska
# M 3.0 - 4 km SSW of Pāhala, Hawaii
# M 5.5 - 64 km WNW of Vinchina, Argentina
# M 4.6 - 44 km SSW of Kilembe, Uganda
# M 5.1 - Kermadec Islands region
# M 2.5 - 1 km N of Kahaluu-Keauhou, Hawaii
# M 4.5 - 42 km NNW of Te Anau, New Zealand
# M 2.7 - 111 km WSW of Akhiok, Alaska
# M 2.7 - 1km ENE of The Geysers, CA
# M 4.5 - 49 km SE of Jiufen, Taiwan
# M 5.5 - Oaxaca, Mexico
# M 2.9 - 55 km S of Whites City, New Mexico
# M 5.0 - 196 km SW of Vaini, Tonga
# M 4.7 - 203 km NNW of Santa Cruz da Graciosa, Portugal
# M 4.0 - 118 km N of Calama, Chile
# M 2.8 - 39 km WNW of Skwentna, Alaska
# M 5.1 - 73 km ESE of Naze, Japan
# M 4.8 - 211 km SSE of Sarangani, Philippines
# M 3.0 - south of Alaska
# M 5.0 - 124 km ESE of ‘Ohonua, Tonga
# M 3.8 - 2 km S of Mount Barker, Australia
# M 2.6 - 1 km WSW of Palomas, Puerto Rico
# M 4.5 - 114 km SSW of Hihifo, Tonga
# M 4.5 - 36 km NNE of Yigo Village, Guam
# M 3.4 - Rat Islands, Aleutian Islands, Alaska
# M 4.2 - 115 km W of Abra Pampa, Argentina
# M 3.7 - 126 km NNE of Suárez, Puerto Rico
# M 2.9 - 11 km WNW of Stanley, Idaho
# M 2.6 - 13 km WNW of Stanley, Idaho
# M 4.8 - 69 km NNW of Ternate, Indonesia
# M 3.2 - 2km E of Pinnacles, CA
# M 4.1 - 76 km NNW of Charlotte Amalie, U.S. Virgin Islands
# M 4.5 - 82 km NNW of Phôngsali, Laos
# M 5.1 - 9 km E of Parapat, Indonesia
# M 5.5 - 102 km SSW of Banda Aceh, Indonesia
# M 3.3 - 13km SE of Bodfish, CA
# M 2.5 - 12km N of New Idria, CA
# M 4.4 - 263 km E of Levuka, Fiji
# M 3.0 - 4 km W of Pāhala, Hawaii
# M 2.6 - 2 km NW of Indios, Puerto Rico
# M 5.1 - 68 km NNE of Puerto Ocopa, Peru
# M 2.9 - 9 km N of Cantwell, Alaska
# M 5.0 - South Sandwich Islands region
# M 3.3 - 57 km S of Whites City, New Mexico
# M 4.3 - south of the Fiji Islands
# M 4.8 - Southwest Indian Ridge
# M 4.3 - 57 km S of Whites City, New Mexico
# M 5.7 - 47 km NW of Abra Pampa, Argentina
# M 3.6 - 80 km NW of Yakutat, Alaska
# M 4.4 - 21 km E of Kirovsk, Russia
# M 4.7 - 278 km WSW of Tual, Indonesia
# M 2.6 - 4 km SW of Pāhala, Hawaii
# M 5.1 - 152 km E of Miyako, Japan
# M 4.4 - 17 km W of San Nicolò, Italy
# M 4.7 - 135 km E of Miyako, Japan
# M 2.8 - 27 km SW of Atka, Alaska
# M 4.3 - 121 km NW of Pante Makasar, Timor Leste
# M 4.4 - 39 km WSW of Fārsān, Iran
# M 5.0 - South Sandwich Islands region
# M 2.8 - 24 km NE of Chase, Alaska
# M 4.9 - 206 km NE of Lospalos, Timor Leste
# M 3.7 - 87 km N of Charlotte Amalie, U.S. Virgin Islands
# M 2.5 - 3 km SW of Guánica, Puerto Rico
# M 4.3 - 111 km SSW of Labuan, Indonesia
# M 2.8 - Rat Islands, Aleutian Islands, Alaska
# M 4.4 - 55 km SE of Mohr, Iran
# M 2.9 - Nevada
# M 3.1 - 33 km NNE of Atka, Alaska
# M 3.1 - 4 km S of Pāhala, Hawaii
# M 4.3 - 64 km N of Manado, Indonesia
# M 3.1 - 37 km NNW of Toyah, Texas
# M 4.4 - 60 km NW of Coquimbo, Chile
# M 5.4 - 70 km ENE of Kimbe, Papua New Guinea
# M 4.6 - 271 km S of Sinabang, Indonesia
# M 4.3 - 86 km SSW of Komodo, Indonesia
# M 4.2 - 287 km NE of Lospalos, Timor Leste
# M 4.3 - 67 km W of Nuquí, Colombia
# M 4.2 - Rat Islands, Aleutian Islands, Alaska
# M 5.0 - Kermadec Islands region
# M 2.6 - 8 km SE of Pole Ojea, Puerto Rico
# M 2.5 - 2 km ESE of Magas Arriba, Puerto Rico
# M 4.6 - western Xizang
# M 2.9 - 6 km E of Pāhala, Hawaii
# M 5.0 - Kermadec Islands region
# M 5.1 - Kermadec Islands region
# M 2.5 - 4 km WSW of La Parguera, Puerto Rico
# M 3.1 - Nevada
# M 4.0 - 6 km SSW of Salvaleón de Higüey, Dominican Republic
# M 3.3 - 46 km N of Arecibo, Puerto Rico
# M 3.7 - 22 km W of Klerksdorp, South Africa
# M 2.8 - 20km SSE of Estacion Coahuila, B.C., MX
# M 4.3 - 66 km ENE of Kabalo, Democratic Republic of the Congo
# M 4.6 - Kermadec Islands, New Zealand
# M 5.1 - 33 km NE of Pujocucho, Peru
# M 4.2 - 26 km S of La Gomera, Guatemala
# M 4.2 - 140 km NW of Ternate, Indonesia
# M 4.3 - 128 km ESE of Iquique, Chile
# M 2.5 - Rat Islands, Aleutian Islands, Alaska
# M 2.7 - 8 km E of Pāhala, Hawaii
# M 4.2 - Fiji region
# M 5.1 - Chagos Archipelago region
# M 2.7 - 9 km S of Volcano, Hawaii
# M 2.7 - 71 km NNE of San Juan, Puerto Rico
# M 2.6 - 25 km WNW of Stanley, Idaho
# M 4.7 - Izu Islands, Japan region
# M 3.3 - 79 km SE of Nikolski, Alaska
# M 5.7 - 15 km WNW of Nopalapan, Mexico
# M 4.9 - 79 km SE of Farkhār, Afghanistan
# M 5.1 - Kermadec Islands, New Zealand
# M 2.7 - 13 km SSW of La Parguera, Puerto Rico
# M 4.9 - Kermadec Islands region
# M 3.8 - 83 km N of Cruz Bay, U.S. Virgin Islands
# M 3.8 - 0km NNW of The Geysers, CA
# M 4.9 - 55 km SW of Jiquilillo, Nicaragua
# M 2.6 - 1 km ESE of Magas Arriba, Puerto Rico
# M 4.8 - 33 km NNE of Fiambalá, Argentina
# M 4.3 - 165 km NNE of Shi Yomi, India
# M 3.0 - Rat Islands, Aleutian Islands, Alaska
# M 3.5 - Rat Islands, Aleutian Islands, Alaska
# M 2.7 - 178 km W of Crescent City, California
# M 4.3 - 2 km NNE of San Nicolas, Philippines
# M 5.0 - 58 km N of Narganá, Panama
# M 3.2 - 20 km NW of San Antonio, Puerto Rico
# M 4.0 - 120 km N of Charlotte Amalie, U.S. Virgin Islands
# M 4.5 - 57 km NW of Bukittinggi, Indonesia
# M 2.5 - 34 km NW of Stanley, Idaho
# M 4.6 - 11 km ESE of Villa Presidente Frei, Ñuñoa, Santiago, Chile, Chile
# M 4.4 - Banda Sea
# M 4.3 - 73 km N of Güiria, Venezuela
# M 4.6 - 125 km WNW of Naha, Japan
# M 4.7 - 127 km ENE of Petropavlovsk-Kamchatsky, Russia
# M 4.6 - 86 km SE of Gorontalo, Indonesia
# M 3.8 - 105 km N of Cruz Bay, U.S. Virgin Islands
# M 2.8 - 32 km SE of Malaga, New Mexico
# M 4.3 - off the coast of Michoacan, Mexico
# M 5.0 - West Chile Rise
# M 4.6 - 147 km NW of Nuku‘alofa, Tonga
# M 5.0 - 37 km NE of Sorong, Indonesia
# M 4.9 - 182 km SW of Lorengau, Papua New Guinea
# M 2.7 - 20km NW of Desert Center, CA
# M 5.5 - 63 km S of Kokopo, Papua New Guinea
# M 3.0 - 33 km WNW of Kalaoa, Hawaii
# M 4.3 - West Chile Rise
# M 3.2 - 4 km SW of Pāhala, Hawaii
# M 5.4 - north of Ascension Island
# M 3.0 - 4 km N of Animas, Puerto Rico
# M 3.0 - 13 km SW of Vardane, Russia
# M 4.3 - Ryukyu Islands, Japan
# M 4.4 - 261 km WSW of Tual, Indonesia
# M 4.0 - 65 km WNW of La Ligua, Chile
# M 4.5 - 36 km S of Nabire, Indonesia
# M 2.8 - 8km NNE of Walker, CA
# M 4.3 - 143 km WNW of Ishikawa, Japan
# M 4.3 - 265 km E of Levuka, Fiji

# %% [markdown]
# **SIDE BAR: GeoJSON?**
#
# Working with geospatial data over the web, you will inevitably encounter called GeoJSON. GeoJSON is just JSON (which is just...???) with a slightly more well-defined schema to distinguish between metadata, spatial features, and classes of spatial features (e.g. points vs. lines vs. polygons).
#
# There's lots of great tools out there for working with GeoJSON, but chief among them is [geojson.io](https://geojson.io). Try copying the first 5 entries from the quakes list into the `features` list on geojson.io and see what you find.
#
# HINT: it's a little bit tricker to go from Python to JSON than from JSON to Python because Python doesn't care about single-quotes vs. double quotes, but JavaScript does. You can use the `json.dumps()` method to convert a Python dictionary to a valid JSON string.

# %%
print(json.dumps(response.json()['features'][:5]))
# Out:
# [{"type": "Feature", "properties": {"mag": 4.8, "place": "44 km NE of Calama, Chile", "time": 1646849043457, "updated": 1646850120040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000h3cz", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h3cz.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 354, "net": "us", "code": "6000h3cz", "ids": ",us6000h3cz,", "sources": ",us,", "types": ",origin,phase-data,", "nst": null, "dmin": 0.712, "rms": 1.52, "gap": 58, "magType": "mb", "type": "earthquake", "title": "M 4.8 - 44 km NE of Calama, Chile"}, "geometry": {"type": "Point", "coordinates": [-68.6028, -22.1939, 111.19]}, "id": "us6000h3cz"}, {"type": "Feature", "properties": {"mag": 2.53, "place": "9km N of Petrolia, CA", "time": 1646848487210, "updated": 1646849122718, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc73703361", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73703361.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "automatic", "tsunami": 0, "sig": 98, "net": "nc", "code": "73703361", "ids": ",nc73703361,", "sources": ",nc,", "types": ",nearby-cities,origin,phase-data,scitech-link,", "nst": 16, "dmin": 0.08162, "rms": 0.07, "gap": 183, "magType": "md", "type": "earthquake", "title": "M 2.5 - 9km N of Petrolia, CA"}, "geometry": {"type": "Point", "coordinates": [-124.2675018, 40.402668, 26.24]}, "id": "nc73703361"}, {"type": "Feature", "properties": {"mag": 3.1, "place": "36 km NNE of Excursion Inlet, Alaska", "time": 1646845405783, "updated": 1646848489185, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak02234qonr5", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02234qonr5.geojson", "felt": 2, "cdi": 2.2, "mmi": null, "alert": null, "status": "automatic", "tsunami": 0, "sig": 148, "net": "ak", "code": "02234qonr5", "ids": ",ak02234qonr5,us6000h3bi,", "sources": ",ak,us,", "types": ",dyfi,origin,phase-data,", "nst": null, "dmin": null, "rms": 1.09, "gap": null, "magType": "ml", "type": "earthquake", "title": "M 3.1 - 36 km NNE of Excursion Inlet, Alaska"}, "geometry": {"type": "Point", "coordinates": [-135.2233, 58.721, 17.7]}, "id": "ak02234qonr5"}, {"type": "Feature", "properties": {"mag": 3.5, "place": "95 km SE of Old Harbor, Alaska", "time": 1646843542006, "updated": 1646844241925, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak02234q9fy0", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02234q9fy0.geojson", "felt": null, "cdi": null, "mmi": 1, "alert": null, "status": "automatic", "tsunami": 0, "sig": 188, "net": "ak", "code": "02234q9fy0", "ids": ",ak02234q9fy0,", "sources": ",ak,", "types": ",origin,phase-data,shakemap,", "nst": null, "dmin": null, "rms": 0.75, "gap": null, "magType": "ml", "type": "earthquake", "title": "M 3.5 - 95 km SE of Old Harbor, Alaska"}, "geometry": {"type": "Point", "coordinates": [-152.1622, 56.615, 0]}, "id": "ak02234q9fy0"}, {"type": "Feature", "properties": {"mag": 5.5, "place": "South Sandwich Islands region", "time": 1646843414969, "updated": 1646844832188, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us6000h3b9", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000h3b9.geojson", "felt": null, "cdi": null, "mmi": 2.689, "alert": "green", "status": "reviewed", "tsunami": 0, "sig": 465, "net": "us", "code": "6000h3b9", "ids": ",us6000h3b9,", "sources": ",us,", "types": ",losspager,origin,phase-data,shakemap,", "nst": null, "dmin": 8.561, "rms": 0.71, "gap": 78, "magType": "mb", "type": "earthquake", "title": "M 5.5 - South Sandwich Islands region"}, "geometry": {"type": "Point", "coordinates": [-25.965, -60.6957, 10]}, "id": "us6000h3b9"}]

# %% [markdown]
# Extracting data from nested dictionaries might be a good job for **list comprehension**:

# %%
d = {
    'magnitude': [q['properties']['mag'] for q in quakes],
    'depth': [q['geometry']['coordinates'][2] for q in quakes]
}
df = pd.DataFrame.from_dict(d)

df.head()
# Out:
#    magnitude   depth
# 0       4.80  111.19
# 1       2.53   26.24
# 2       3.10   17.70
# 3       3.50    0.00
# 4       5.50   10.00

# %%
print(df.describe())
# Out:
#         magnitude       depth
# count  288.000000  288.000000
# mean     3.914722   54.608725
# std      0.923832   91.404040
# min      2.450000   -2.660000
# 25%      3.000000   10.000000
# 50%      4.175000   13.975000
# 75%      4.600000   64.895000
# max      6.100000  644.460000

# %%
df.plot(x='magnitude', y='depth', kind='scatter')

# %% [markdown]
# # 3. Geocoding
#
# Now on to the main course: geocoding APIs.

# %% [markdown]
# ## 3.1. What is geocoding?

# %% [markdown]
# **Geocoding** describes the process of converting place names and addresses to geographic coordinates (e.g. lat/lon).

# %% [markdown]
# <center><img src="https://dmpublisher.s3-us-west-2.amazonaws.com/old-dm/directionsmag.com/ee/images/newsletter/2004/10_20/EDramowicz_Figure1_lg.gif"></center>

# %% [markdown]
# Reverse geocoding is just the opposite process: using geographic coordinates to extract meaningful place names/addresses.

# %% [markdown]
# Perhaps this sounds like a dull topic, but **geocoding is a fundamental tool for anyone wishing to do spatial data analysis**.
#
# Why?

# %% [markdown]
# - 9 times out of 10, your data will have _either_ geographic coordinates _or_ administrative boundary names, but not both!
# - 9 times out of 10 you will want to use additional data sources for which the above statement also applies
# - Geocoding allows you to translate between the two (e.g. merging Census data into Craiglist rental listings)

# %% [markdown]
# ## 3.2 Geocoding with the Mapbox API

# %% [markdown]
# Services like Google Maps and Mapbox have various APIs that let you access its services through code instead of through GUI apps. This one from Mapbox lets you look up the latitude-longitude coordinates of street addresses. You'll need to create a Mapbox API token in order to use this API, which you can do by following the instructions [here ](https://www.mapbox.com/signin/?route-to=%22/account/access-tokens%22) if you have not alread done so.

# %% [markdown]
# The Mapbox API queries work just like the ones we've already seen, but now we're including our own query parameters in the URL endpoint!
#
# **API documentation:**
# https://www.mapbox.com/api-documentation/#geocoding
#
# **API endpoint:**
# https://api.mapbox.com/geocoding/v5/mapbox.places
#
# **API endpoint with query parameters:**
# https://api.mapbox.com/geocoding/v5/mapbox.places/Wurster+Hall.json?access_token=pk.eyJ1IjoiY3AyNTVkZW1vIiwiYSI6ImRPcTlnTUEifQ.3C0d0Nk_rcwV-8JF29PU-w

# %% [markdown]
# ### 3.2.1. A word about API keys, tokens, and passwords in general
#
# It's never a good idea to print an API key in a public document, including a script or notebook like this one. Particularly when you're using Git, deleting private data after you've already committed the change won't remove the data from your project history!
#
# Instead, its good practice to create a small .json file which you can read into Python without ever having to print its contents. In this case, let's use a text editor to create a file named **mapbox_api_key.json** and put it in the `data/` directory. It's contents should look like this:
#
# ```javascript
# {"key": "<your API key here>"}
# ```
#
# Now we can read the API key from disk:

# %%
import json

with open("data/mapbox_api_key.json", 'r') as f:
    key_file = f.read()
    
my_api_key = json.loads(key_file)['key']

# %% [markdown]
# ### 3.2.2. Constructing an API query
# Now we're ready to format our API request.

# %%
import requests

base_url = 'https://api.mapbox.com/geocoding/v5/mapbox.places/'
address = 'Wurster Hall'
params = {
    'limit': 1,  # just get the first record
    'access_token': my_api_key}

url = requests.Request('GET', base_url + address + '.json', params=params).prepare().url

# %% [markdown]
# This looks a little more complicated than what we saw last class. The main reason for this is that we are now doing more than simply submitting a `GET` request to URL whose full endpoint we know in advance. Instead, we just know the base URL of our API, and are using strings and key-value pairs to format the rest of the endpoint. This is pretty straightforward with one exception: HTTP doesn't know how to handle white space `" "` and many other special characters. So we are relying on the `Request.prepare()` method to take our input data and format it into a string that can be understood by HTTP.
#
# You can try printing the url in the cell below to see what this formatted version of the URL looks like, but be careful because it will contain your API key!

# %%
print(url)
# Out:
# https://api.mapbox.com/geocoding/v5/mapbox.places/Wurster%20Hall.json?limit=1&access_token=pk.eyJ1IjoiZ2FtYmFkb29vIiwiYSI6ImNrNnM1dHp0bTBkazkzZGxhemlyNjYyeDMifQ.NLAJm7NujfJ8y_oKjFvHGA

# %% [markdown]
# ### 3.2.3. Making the request and parsing the response

# %%
from pprint import PrettyPrinter as pp
response = requests.get(url)
results = response.text
data = json.loads(results)
data
# Out:
# {'type': 'FeatureCollection',
#  'query': ['wurster', 'hall'],
#  'features': [{'id': 'poi.472446416066',
#    'type': 'Feature',
#    'place_type': ['poi'],
#    'relevance': 1,
#    'properties': {'foursquare': '4b56554cf964a520ce0b28e3',
#     'landmark': True,
#     'address': '230 Wurster Hall #1820',
#     'category': 'college art building, building'},
#    'text': 'Wurster Hall / College of Environmental Design',
#    'place_name': 'Wurster Hall / College of Environmental Design, 230 Wurster Hall #1820, Berkeley, California 94704, United States',
#    'center': [-122.254883, 37.870818],
#    'geometry': {'coordinates': [-122.254883, 37.870818], 'type': 'Point'},
#    'context': [{'id': 'neighborhood.12468009734905880',
#      'text': 'University of California'},
#     {'id': 'postcode.13849498828668840', 'text': '94704'},
#     {'id': 'place.9820619379990170',
#      'wikidata': 'Q484678',
#      'text': 'Berkeley'},
#     {'id': 'district.11187960009291250',
#      'wikidata': 'Q107146',
#      'text': 'Alameda County'},
#     {'id': 'region.9803118085738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2022 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %% [markdown]
# Does anyone think they have what it takes to extract the coordinates from our API response data?

# %% [markdown]
# ### 3.2.5 Exercises
#
# 1. Search for some other addresses or landmarks!
# 2. Try storing your code as a function named `get_coords()` so that you need only supply a place name and your function will return the coordinates as list or tuple:
#    ```python
#     def get_coords(place_str):
#
#         # do something with "place_str"
#
#         return coords
#
#    ```
# 2. Take a look at the [API documentation](https://www.mapbox.com/api-documentation/#geocoding). Can you figure out how to retrieve other points of interest near Wurster Hall?

# %%
# %%html
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/2KnJ183quw14FCd3Lb3pqL?utm_source=generator" width="30%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>
# Out:
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/2KnJ183quw14FCd3Lb3pqL?utm_source=generator" width="30%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# ### 3.2.4. The Mapbox SDK

# %% [markdown]
# Mapbox also maintans its own Python package which makes it a little easier to execute HTTP requests against its API. You can find the documentation [here](https://mapbox-mapbox.readthedocs-hosted.com/en/latest/index.html)
#
# NOTE: the Mapbox Python API seems to be a bit buggy. In particular it doesn't seem to support Python > 3.9. If you encounter any issues trying to import modules from this library, the best thing to do is to roll back your Python version. From a terminal, you can do:
#
# ```bash
# conda install python=3.9
# ```
#
# and then restart your notebook kernel using the Kernel drop down menu in the menu panel above (or by typing `00` in rapid succession in command mode).

# %% [markdown]
# #### 3.2.4.1. Forward Geocoding
#
# Forward geocoding is the one we have looked at so far using an API endpoint.  It takes an address or a place name and returns the geographic coordinates of that location.  Let's look at it again using the Mapbox Python SDK.

# %%
from mapbox import Geocoder
import os

geocoder = Geocoder(access_token=my_api_key)

# %% [markdown]
# OK, now we can get to work on the geocoding... let's try geocoding Freehouse Restaurant, which is at 2700 Bancroft Way.

# %%
response = geocoder.forward('2700 Bancroft Way, Berkeley, CA 94704', limit=1)
data = response.json()
data
# Out:
# {'type': 'FeatureCollection',
#  'query': ['2700', 'bancroft', 'way', 'berkeley', 'ca', '94704'],
#  'features': [{'id': 'address.7730712976723886',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'parcel'},
#    'text': 'Bancroft Way',
#    'place_name': '2700 Bancroft Way, Berkeley, California 94704, United States',
#    'center': [-122.254267, 37.868965],
#    'geometry': {'type': 'Point', 'coordinates': [-122.254267, 37.868965]},
#    'address': '2700',
#    'context': [{'id': 'neighborhood.14897580184476970',
#      'text': 'South Campus'},
#     {'id': 'postcode.13849498828668840', 'text': '94704'},
#     {'id': 'place.9820619379990170',
#      'wikidata': 'Q484678',
#      'text': 'Berkeley'},
#     {'id': 'district.11187960009291250',
#      'wikidata': 'Q107146',
#      'text': 'Alameda County'},
#     {'id': 'region.9803118085738010',
#      'short_code': 'US-CA',
#      'wikidata': 'Q99',
#      'text': 'California'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2022 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %% [markdown]
# Another random address to geocode:

# %%
response = geocoder.forward('120 East 13th Street, Manhattan, New York, New York 10003', limit = 1)
first = response.json()['features'][0]
print(first['place_name'])
print([coord for coord in first['geometry']['coordinates']])
# Out:
# 120 East 13th Street, New York, New York 10003, United States
# [-73.98893, 40.73295]

# %% [markdown]
# #### 3.2.4.2 Creating a dataframe from multiple API queries
#
# Can you think of a good way to write a loop to geocode those addresses and add them to a dataframe?  Let's try one way to do this.

# %%
import pandas as pd
data = pd.DataFrame(index=[],columns=['address','lat','lon'])

addrs = [
    '3028 Regent St., Berkeley, California, 94705',
    '1511 Julia St, Berkeley, California, 94703',
    '2700 Bancroft, Berkeley, California, 94704']

# %%
for i in range(len(addrs)):
    geoadress=geocoder.forward(addrs[i], limit = 1).geojson()['features'][0]['geometry']['coordinates']
    data.loc[i, 'address']=addrs[i]
    data.loc[i, 'lon']=geoadress[0]
    data.loc[i, 'lat']=geoadress[1]
data
# Out:
#                                         address        lat         lon
# 0  3028 Regent St., Berkeley, California, 94705   37.85393  -122.26662
# 1    1511 Julia St, Berkeley, California, 94703  37.854495  -122.27862
# 2    2700 Bancroft, Berkeley, California, 94704  37.868965 -122.254267

# %% [markdown]
# #### 3.2.4.3 Reverse Geocoding
#
# Reverse geocoding does what it sounds like. It takes coordinates and returns an address or other place type.  Options for place type include: country, region, postcode, district, place, locality, neighborhood, address,and poi.
#
# Let's start by using the coordinates of the address we just got from forward geocoding, and get the address back from reverse geocoding of those coordinates.

# %%
response = geocoder.reverse(lat=37.868965, lon=-122.254267)
features = response.geojson()['features']
features
# Out:
# [{'id': 'address.7730712976723886',
#   'type': 'Feature',
#   'place_type': ['address'],
#   'relevance': 1,
#   'properties': {'accuracy': 'parcel'},
#   'text': 'Bancroft Way',
#   'place_name': '2700 Bancroft Way, Berkeley, California 94704, United States',
#   'center': [-122.2542675, 37.868965],
#   'geometry': {'type': 'Point', 'coordinates': [-122.2542675, 37.868965]},
#   'address': '2700',
#   'context': [{'id': 'neighborhood.14897580184476970', 'text': 'South Campus'},
#    {'id': 'postcode.13849498828668840', 'text': '94704'},
#    {'id': 'place.9820619379990170', 'wikidata': 'Q484678', 'text': 'Berkeley'},
#    {'id': 'district.11187960009291250',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'neighborhood.14897580184476970',
#   'type': 'Feature',
#   'place_type': ['neighborhood'],
#   'relevance': 1,
#   'properties': {},
#   'text': 'South Campus',
#   'place_name': 'South Campus, Berkeley, California, United States',
#   'bbox': [-122.265991211, 37.864250183, -122.250457764, 37.869602203],
#   'center': [-122.2585, 37.8667],
#   'geometry': {'type': 'Point', 'coordinates': [-122.2585, 37.8667]},
#   'context': [{'id': 'postcode.13849498828668840', 'text': '94704'},
#    {'id': 'place.9820619379990170', 'wikidata': 'Q484678', 'text': 'Berkeley'},
#    {'id': 'district.11187960009291250',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'postcode.13849498828668840',
#   'type': 'Feature',
#   'place_type': ['postcode'],
#   'relevance': 1,
#   'properties': {},
#   'text': '94704',
#   'place_name': 'Berkeley, California 94704, United States',
#   'bbox': [-122.27405789, 37.859768015, -122.238420049, 37.881203815],
#   'center': [-122.26, 37.87],
#   'geometry': {'type': 'Point', 'coordinates': [-122.26, 37.87]},
#   'context': [{'id': 'place.9820619379990170',
#     'wikidata': 'Q484678',
#     'text': 'Berkeley'},
#    {'id': 'district.11187960009291250',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'place.9820619379990170',
#   'type': 'Feature',
#   'place_type': ['place'],
#   'relevance': 1,
#   'properties': {'wikidata': 'Q484678'},
#   'text': 'Berkeley',
#   'place_name': 'Berkeley, California, United States',
#   'bbox': [-122.327101938, 37.84596, -122.21355766, 37.920357393],
#   'center': [-122.2729, 37.8708],
#   'geometry': {'type': 'Point', 'coordinates': [-122.2729, 37.8708]},
#   'context': [{'id': 'district.11187960009291250',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'district.11187960009291250',
#   'type': 'Feature',
#   'place_type': ['district'],
#   'relevance': 1,
#   'properties': {'wikidata': 'Q107146'},
#   'text': 'Alameda County',
#   'place_name': 'Alameda County, California, United States',
#   'bbox': [-122.342665, 37.454186, -121.469214, 37.905824],
#   'center': [-121.91, 37.65],
#   'geometry': {'type': 'Point', 'coordinates': [-121.91, 37.65]},
#   'context': [{'id': 'region.9803118085738010',
#     'short_code': 'US-CA',
#     'wikidata': 'Q99',
#     'text': 'California'},
#    {'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'region.9803118085738010',
#   'type': 'Feature',
#   'place_type': ['region'],
#   'relevance': 1,
#   'properties': {'short_code': 'US-CA', 'wikidata': 'Q99'},
#   'text': 'California',
#   'place_name': 'California, United States',
#   'bbox': [-124.514829293866,
#    32.5019647016422,
#    -114.131210004164,
#    42.0095039998439],
#   'center': [-119.699375153073, 37.0743595873],
#   'geometry': {'type': 'Point',
#    'coordinates': [-119.699375153073, 37.0743595873]},
#   'context': [{'id': 'country.19678805456372290',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'country.19678805456372290',
#   'type': 'Feature',
#   'place_type': ['country'],
#   'relevance': 1,
#   'properties': {'wikidata': 'Q30', 'short_code': 'us'},
#   'text': 'United States',
#   'place_name': 'United States',
#   'bbox': [-179.9, 18.8163608007951, -66.8847646185949, 71.4202919997506],
#   'center': [-97.9222112121185, 39.3812661305678],
#   'geometry': {'type': 'Point',
#    'coordinates': [-97.9222112121185, 39.3812661305678]}}]

# %%
for f in features:
    print('{place_type[0]}'.format(**f) + ':', '{place_name}'.format(**f))
# Out:
# address: 2700 Bancroft Way, Berkeley, California 94704, United States
# neighborhood: South Campus, Berkeley, California, United States
# postcode: Berkeley, California 94704, United States
# place: Berkeley, California, United States
# district: Alameda County, California, United States
# region: California, United States
# country: United States

# %% [markdown]
# ### Bonus Section: Getting Directions from Mapbox
#
# You can put in start and end locations and call the Mapbox directions API to get suggested directions as a sequence of coordinates you could plot on a map.

# %%
from mapbox import Directions
help(Directions)
# Out:
# Help on class Directions in module mapbox.services.directions:
#
# class Directions(mapbox.services.base.Service)
#  |  Directions(access_token=None, host=None, cache=None)
#  |
#  |  Access to the Directions v5 API.
#  |
#  |  Method resolution order:
#  |      Directions
#  |      mapbox.services.base.Service
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  directions(self, features, profile='mapbox/driving', alternatives=None, geometries=None, overview=None, steps=None, continue_straight=None, waypoint_snapping=None, annotations=None, language=None, **kwargs)
#  |      Request directions for waypoints encoded as GeoJSON features.
#  |
#  |      Parameters
#  |      ----------
#  |      features : iterable
#  |          An collection of GeoJSON features
#  |      profile : str
#  |          Name of a Mapbox profile such as 'mapbox.driving'
#  |      alternatives : bool
#  |          Whether to try to return alternative routes, default: False
#  |      geometries : string
#  |          Type of geometry returned (geojson, polyline, polyline6)
#  |      overview : string or False
#  |          Type of returned overview geometry: 'full', 'simplified',
#  |          or False
#  |      steps : bool
#  |          Whether to return steps and turn-by-turn instructions,
#  |          default: False
#  |      continue_straight : bool
#  |          Direction of travel when departing intermediate waypoints
#  |      radiuses : iterable of numbers or 'unlimited'
#  |          Must be same length as features
#  |      waypoint_snapping : list
#  |          Controls snapping of waypoints
#  |
#  |          The list is zipped with the features collection and must
#  |          have the same length. Elements of the list must be one of:
#  |
#  |          - A number (interpretted as a snapping radius)
#  |          - The string 'unlimited' (unlimited snapping radius)
#  |          - A 3-element tuple consisting of (radius, angle, range)
#  |          - None (no snapping parameters specified for that waypoint)
#  |      annotations : str
#  |          Whether or not to return additional metadata along the route
#  |
#  |          Possible values are: 'duration', 'distance', 'speed', and
#  |          'congestion'. Several annotations can be used by joining
#  |          them with ','.
#  |      language : str
#  |          Language of returned turn-by-turn text instructions,
#  |          default: 'en'
#  |
#  |      Returns
#  |      -------
#  |      requests.Response
#  |          The response object has a geojson() method for access to
#  |          the route(s) as a GeoJSON-like FeatureCollection
#  |          dictionary.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  baseuri
#  |      The service's base URI
#  |
#  |      Returns
#  |      -------
#  |      str
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  api_name = 'directions'
#  |
#  |  api_version = 'v5'
#  |
#  |  valid_annotations = ['duration', 'distance', 'speed']
#  |
#  |  valid_geom_encoding = ['geojson', 'polyline', 'polyline6']
#  |
#  |  valid_geom_overview = ['full', 'simplified', False]
#  |
#  |  valid_profiles = ['mapbox/driving', 'mapbox/driving-traffic', 'mapbox/...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from mapbox.services.base.Service:
#  |
#  |  __init__(self, access_token=None, host=None, cache=None)
#  |      Constructs a Service object
#  |
#  |      This method should be overridden by subclasses.
#  |
#  |      Parameters
#  |      ----------
#  |      access_token : str
#  |          Mapbox access token string.
#  |      host : str, optional
#  |          Mapbox API host (advanced usage only).
#  |      cache : CacheControl cache instance (Dict or FileCache), optional
#  |          Optional caching, not generally needed.
#  |
#  |      Returns
#  |      -------
#  |      Service
#  |
#  |  handle_http_error(self, response, custom_messages=None, raise_for_status=False)
#  |      Converts service errors to Python exceptions
#  |
#  |      Parameters
#  |      ----------
#  |      response : requests.Response
#  |          A service response.
#  |      custom_messages : dict, optional
#  |          A mapping of custom exception messages to HTTP status codes.
#  |      raise_for_status : bool, optional
#  |          If True, the requests library provides Python exceptions.
#  |
#  |      Returns
#  |      -------
#  |      None
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from mapbox.services.base.Service:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  username
#  |      The username in the service's access token
#  |
#  |      Returns
#  |      -------
#  |      str
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from mapbox.services.base.Service:
#  |
#  |  default_host = 'api.mapbox.com'

# %%
service = Directions()

origin = {
        'type': 'Feature',
        'properties': {'name': 'Portland, OR'},
        'geometry': {
        'type': 'Point',
        'coordinates': [-122.7282, 45.5801]}}
destination = {
    'type': 'Feature',
    'properties': {'name': 'Bend, OR'},
    'geometry': {
    'type': 'Point',
    'coordinates': [-121.3153, 44.0582]}}

# %%
response = service.directions([origin, destination],'mapbox/driving')
driving_routes = response.geojson()
driving_routes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-af88ef71d874> in <module>
#       1 response = service.directions([origin, destination],'mapbox/driving')
# ----> 2 driving_routes = response.geojson()
#       3 driving_routes
#
# C:\ProgramData\Anaconda3\lib\site-packages\mapbox\services\directions.py in geojson()
#     245
#     246         def geojson():
# --> 247             return self._geojson(resp.json(), geom_format=geometries)
#     248         resp.geojson = geojson
#     249         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\mapbox\services\directions.py in _geojson(self, data, geom_format)
#     254             'features': []}
#     255
# --> 256         for route in data['routes']:
#     257             if geom_format == 'geojson':
#     258                 geom = route['geometry']
#
# KeyError: 'routes'

# %%
# %%html
#
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/2KnJ183quw14FCd3Lb3pqL?utm_source=generator" width="30%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>
# Out:
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/2KnJ183quw14FCd3Lb3pqL?utm_source=generator" width="30%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# ## 3.3 Geocoding with Nominatim

# %% [markdown]
# Open source rules! Nominatim is an open source geocoding platform that is managed by OpenStreetMap (I think). Try using the Nominatim API to geocode or reverse geocode some data of interest! You can find the Nominamtim docs [here](https://nominatim.org/release-docs/develop/api/Search/)
#
# Hint: whenever you're using an API for the first time, its always a good idea to start by trying to find some example queries in the documentation, and then tweaking them to meet your needs.

# %%
query_str = 'wurster hall'
url = "https://nominatim.openstreetmap.org/?addressdetails=1&q={0}&format=json&limit=1".format(query_str)
res = requests.get(url)

# %%
res.json()
# Out:
# [{'place_id': 283158268,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 6415953,
#   'boundingbox': ['37.870117', '37.8710312', '-122.2552795', '-122.25431'],
#   'lat': '37.8705723',
#   'lon': '-122.25489935163237',
#   'display_name': 'Bauer Wurster Hall, Wurster Courtyard, Southside, Berkeley, Alameda County, California, 94720-1076, United States',
#   'class': 'building',
#   'type': 'university',
#   'importance': 0.201,
#   'address': {'building': 'Bauer Wurster Hall',
#    'road': 'Wurster Courtyard',
#    'neighbourhood': 'Southside',
#    'city': 'Berkeley',
#    'county': 'Alameda County',
#    'state': 'California',
#    'postcode': '94720-1076',
#    'country': 'United States',
#    'country_code': 'us'}}]

# %% [markdown]
# ## 3.4 Exercise - Reverse geocoding with the FCC API
#
# Let's load the Craigslist rental listings again and quickly clean it up using the same code we previously used:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/bay.csv')

# clean price and neighborhood
df.price = df.price.str.strip('$').astype('float64')
df.neighborhood = df.neighborhood.str.strip().str.strip('(').str.strip(')')

# break out the date into month day year columns
df['month'] = df['date'].str.split().str[0]
df['day'] = df['date'].str.split().str[1].astype('int32')
df['year'] = df['date'].str.split().str[2].astype('int32')
del df['date']

# extract bedrooms and square footage
def clean_bdrm(value):

    if isinstance(value, str):
        end = value.find('br')

        if end == -1:
            return
        
        else:
            start = value.find('/') + 2
            return int(value[start:end])

    else:
        return
    
def clean_sqft(value):

    if isinstance(value, str):
        end = value.find('ft')
        
        if end == -1:
            return

        else:
            if value.find('br') == -1:
                start = value.find('/') + 2
            else:
                start = value.find('-') + 2

            return int(value[start:end])

    else:
        return
    
df['sqft'] = df['beds_sqft'].map(clean_sqft)
df['bedrooms'] = df['beds_sqft'].map(clean_bdrm)
df.head()

# %% [markdown]
# And now let's use the FCC [Census Block Conversions API](https://geo.fcc.gov/api/census/) to turn lat/long into a block FIPS code. FIPS codes contain from left to right: the location's 2-digit state code, 3-digit county code, 6-digit census tract code, and 4-digit census block code (the first digit of which is the census block group code). With a FIPS code in hand, you can easily merge your data against Census records.
#
# Here's a sample API query to get you started:

# %%
lat = 34.537094
lon = -82.630303
url = 'https://geo.fcc.gov/api/census/block/find?latitude={0}&longitude={1}&format=json'.format(lat, lon)
response = requests.get(url)
data = response.json()
data

# %% [markdown]
# Your job now is to write some Python code to get the FIPS code for every row in the Craigslist rental data, and store that FIPS code as a new column in the dataframe. You might consider using [`df.iterrows()`](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.iterrows.html) to loop through each row of the dataframe one at a time, or if you're feeling fancy, you could define a function and use a vectorized approach (e.g. `df.apply()` or `df.map()`) to run the function on each row of your dataframe without any loops at all!
#
# **CAUTION: PLEASE DO NOT RUN THIS IN CLASS!!!** If we are all doing this at the same time on the same internet connection, you might get our IP address blacklisted by querying the API too many times.
#
# A few tips:
# - Since the API is SLOW for processing a lot of records, and works one record at a time, test out your code using only a few records until you are positive you have it working correctly. It may take several minutes to grind through all the records. You might want to print the row you are processing...maybe every 10th row, to give you some sense of how it is progressing.
# - Watch out for those missing lat-longs. You'll probably want to skip them since the API won't know what to do with them.
# - Consider adding some conditional logic to handle failed HTTP requests. This will prevent you from having to start your iteration over every time your program encounters an error

# %%
# %%html
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/5kqMiwRHsewDj42jxMJSeW?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# # 4. The Census API

# %% [markdown]
# Whatever "Urban Informatics" is or isn't, more often than not you'll find it useful to refer to census data. In this course, we'll be looking at capital-C Census data, i.e. the US Census, if for no other reason than the fact that it is being taught at UC Berkeley which happens to be located in California which happens to be located in the United States. Also, US Census data rocks!
#
# **Question**: Does anyone know of other countries that have good, publically available census data?

# %% [markdown]
# The US Census provides API endpoints for most of its public data. You can find a list of them, along with links to their documentation, [here](https://www.census.gov/data/developers/data-sets.html).
#
# You can use those endpoints to construct your own custom queries and get the data you want by sending HTTP requests to those URLs. For example, to get the total population from 2018 in Alameda County, you can do:

# %%
# define parameters of our API query
acs_var = 'B01001_001E'  # total pop
state = '06'  # CA
counties = ['001', '075']  # Alameda and SF
year = 2018

# format the URL
counties_str = ','.join(counties)
url = "https://api.census.gov/data/{0}/acs/acs5?get={1}&for=county:{2}&in=state:{3}".format(
    year, acs_var, counties_str, state)

# execute the HTTP request
res = requests.get(url)
pd.DataFrame(res.json())

# %% [markdown]
# ## 4.1. Getting a Census API key
# A word of warning. These Census API queries may or may not work for you without specifying an API key. It's probably a good idea to get one anyways, because you will eventually be asked for it after enough queries. You can do that [here](https://api.census.gov/data/key_signup.html)

# %% [markdown]
# ## 4.2. Census API Python Library

# %% [markdown]
# One of the great things about working with open source software and open data is that people are publishing useful tools all the time that you can use to make your life easier. In the case of Census data, there are multiple Python libraries to choose from which are designed to make it a little easier to interact with the Census API.
#
# We'll focus on one that's simply called [census](https://github.com/datamade/census). You _will_ need a Census API key to use this package.
#
# Use the instructions on that GitHub repo to use `pip` to install the `census` package, along with its sister package `us`.

# %%
from census import Census
from us import states

# I store my API key stored as an environment variable rather than a .json file
census_key = os.getenv("CENSUS_API")  

c = Census(census_key, year=year)
res = c.acs5.get((
    'NAME', acs_var), {
    'for': 'county:{}'.format(counties_str),
    'in': 'state:{}'.format(states.CA.fips)
})

pd.DataFrame(res)

# %%
acs_df = pd.DataFrame()

for year in range(2010, 2018):
    c = Census(census_key, year=year)
    res = c.acs1.get((
        'NAME', acs_var), {
        'for': 'county:{}'.format(counties_str),
        'in': 'state:{}'.format(states.CA.fips)
    })

    year_df = pd.DataFrame(res)
    year_df['year'] = year
    acs_df = pd.concat((acs_df, year_df), ignore_index=True)

# %%
import seaborn as sns
sns.lineplot(data=acs_df, x='year', y=acs_var, hue='NAME')

# %% [markdown]
# ## 4.3 More exercises!
#
# Your turn:
# 1. Look up the latitude and longitude of your home address using forward geocoding
# 2. Use the latitude and longitude from that to get the census block of your home address
# 3. Challenge problem: create a dataframe with 3 street addresses and a description column with labels for these locations, and write code that will iterate through them, get the latitude and longitude for each, and the FIPS block code, County name, and write these addresses, lat and long, and FIPS Block code and County names to a dataframe.

# %%
# %%html
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/4KBULZasCMBDKHY8IPUCML?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# # 5. Summary

# %% [markdown]
# By this point in the class you have all the tools you need to:
# 1. find interesting data sets
# 1. load them into Python
# 1. explore, clean, and manipulate that data
# 1. combine it with external administrative or demographic data from the Census
# 1. create charts and visualizations to communicate your findings
# 1. save your new data to disk so you can come back to it later

# %% [markdown]
# # 6. For next time

# %% [markdown]
# - We're about to enter my favorite module of this course: **Working with Geospatial Data**. Some of you have considerable experience with GIS already, and are very comfortable with concepts like coordinate reference systems and map projections, and how to deal with these when working with spatial data.  If so, you might not need to spend much time with the readings for next session, but if not, please at least familiarize yourself with the material from the first two links on the syllabus:
#   - [mapschool.io](https://mapschool.io/)
#   - Part I of [Geographic Data Science with Python](https://geographicdata.science/book/notebooks/00_toc.html)
#
# - We will also be using the GeoPandas Python library, so browse the documentation [here](http://geopandas.org/) and install it ahead of time.

# %% [markdown]
# # 7. Questions?
